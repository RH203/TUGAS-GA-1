# %%
import random

# Tuning parameter
POPULATION_SIZE = 6
GEN_LENGTH = 4  # Panjang kromosom (a, b, c, d)
GENE_MIN = 0
GENE_MAX = 30
CROSSOVER_RATE = 0.25
MUTATION_RATE = 0.10
MAX_GENERATIONS = 100

# %%
# Fungsi untuk mengevaluasi nilai fitness dari sebuah kromosom
def fitness(chromosome):
    """
    Menghitung nilai fitness dari sebuah kromosom.
    
    Parameters:
    chromosome (list): List berisi nilai a, b, c, dan d.
    
    Returns:
    float: Nilai fitness yang dihitung berdasarkan selisih dengan nilai tujuan.
    """
    a, b, c, d = chromosome
    objective_value = abs((a + 2 * b + 3 * c + 4 * d) - 30)
    fitness_value = 1 / (1 + objective_value)
    print(f"Evaluasi fitness: {chromosome} -> Fitness: {fitness_value:.5f}")
    return fitness_value

# %%
# Fungsi untuk menghasilkan populasi awal
def initialize_population():
    """
    Menghasilkan populasi awal secara acak.
    
    Returns:
    list: Daftar kromosom yang berisi populasi awal.
    """
    print("Inisialisasi populasi awal...")
    population = [[random.randint(GENE_MIN, GENE_MAX) for _ in range(GEN_LENGTH)] for _ in range(POPULATION_SIZE)]
    print(f"Populasi awal: {population}")
    return population

# %%
# Fungsi seleksi menggunakan metode roulette wheel
def selection(population, fitness_values):
    """
    Memilih populasi baru menggunakan metode seleksi roulette wheel.
    
    Parameters:
    population (list): Daftar kromosom yang ada dalam populasi.
    fitness_values (list): Daftar nilai fitness dari populasi.
    
    Returns:
    list: Populasi baru hasil seleksi.
    """
    print("Melakukan seleksi menggunakan metode roulette wheel...")
    total_fitness = sum(fitness_values)
    probabilities = [f / total_fitness for f in fitness_values]
    cumulative_probs = [sum(probabilities[:i+1]) for i in range(len(probabilities))]
    new_population = []
    
    for _ in range(POPULATION_SIZE):
        r = random.random()
        for i, cum_prob in enumerate(cumulative_probs):
            if r <= cum_prob:
                new_population.append(population[i])
                break
    print(f"Populasi setelah seleksi: {new_population}")
    return new_population

# %%
# Fungsi crossover satu titik
def crossover(population):
    """
    Melakukan crossover satu titik pada populasi.
    
    Parameters:
    population (list): Daftar kromosom yang ada dalam populasi.
    
    Returns:
    list: Populasi baru hasil crossover.
    """
    print("Melakukan crossover...")
    new_population = []
    for i in range(0, POPULATION_SIZE, 2):
        if random.random() < CROSSOVER_RATE:
            crossover_point = random.randint(1, GEN_LENGTH - 1)
            parent1, parent2 = population[i], population[i+1]
            child1 = parent1[:crossover_point] + parent2[crossover_point:]
            child2 = parent2[:crossover_point] + parent1[crossover_point:]
            new_population.extend([child1, child2])
            print(f"Crossover antara {parent1} dan {parent2} menghasilkan {child1} dan {child2}")
        else:
            new_population.extend([population[i], population[i+1]])
    return new_population

# %%
# Fungsi mutasi
def mutate(population):
    """
    Melakukan mutasi pada populasi.
    
    Parameters:
    population (list): Daftar kromosom yang ada dalam populasi.
    
    Returns:
    list: Populasi baru setelah mutasi.
    """
    print("Melakukan mutasi...")
    total_genes = GEN_LENGTH * POPULATION_SIZE
    num_mutations = int(MUTATION_RATE * total_genes)
    for _ in range(num_mutations):
        chromosome_idx = random.randint(0, POPULATION_SIZE - 1)
        gene_idx = random.randint(0, GEN_LENGTH - 1)
        old_value = population[chromosome_idx][gene_idx]
        population[chromosome_idx][gene_idx] = random.randint(GENE_MIN, GENE_MAX)
        print(f"Mutasi pada kromosom {chromosome_idx} gen {gene_idx}: {old_value} -> {population[chromosome_idx][gene_idx]}")
    return population

# %%
# Fungsi utama algoritma genetika
def genetic_algorithm():
    """
    Menjalankan algoritma genetika untuk mencari solusi terbaik.
    
    Returns:
    list: Kromosom terbaik yang ditemukan selama proses.
    """
    print("Memulai algoritma genetika...")
    population = initialize_population()
    
    for generation in range(MAX_GENERATIONS):
        print(f"\nGenerasi {generation}:")
        
        # Step 2: Evaluasi
        fitness_values = [fitness(chromosome) for chromosome in population]
        
        # Cek apakah solusi sudah ditemukan
        if max(fitness_values) == 1:
            best_index = fitness_values.index(max(fitness_values))
            print(f"Solusi ditemukan di generasi {generation}: {population[best_index]}")
            return population[best_index]
        
        # Step 3: Seleksi
        population = selection(population, fitness_values)
        
        # Step 4: Crossover
        population = crossover(population)
        
        # Step 5: Mutasi
        population = mutate(population)
        
        print(f"Generasi {generation} Fitness Terbaik: {max(fitness_values)}")
    
    # Jika tidak ditemukan solusi yang tepat, kembalikan solusi terbaik yang ditemukan
    best_index = fitness_values.index(max(fitness_values))
    print(f"Tidak ditemukan solusi yang tepat. Pendekatan terbaik: {population[best_index]}")
    return population[best_index]

# %%
# main function
best_solution = genetic_algorithm()
print(f"\nSolusi terbaik: a = {best_solution[0]}, b = {best_solution[1]}, c = {best_solution[2]}, d = {best_solution[3]}")
# Out:
# Memulai algoritma genetika...
# Inisialisasi populasi awal...
# Populasi awal: [[24, 25, 29, 18], [25, 13, 23, 19], [12, 10, 16, 20], [19, 0, 12, 14], [13, 7, 4, 7], [15, 8, 3, 28]]
#
# Generasi 0:
# Evaluasi fitness: [24, 25, 29, 18] -> Fitness: 0.00490
# Evaluasi fitness: [25, 13, 23, 19] -> Fitness: 0.00599
# Evaluasi fitness: [12, 10, 16, 20] -> Fitness: 0.00763
# Evaluasi fitness: [19, 0, 12, 14] -> Fitness: 0.01220
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [15, 8, 3, 28] -> Fitness: 0.00813
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[13, 7, 4, 7], [13, 7, 4, 7], [25, 13, 23, 19], [12, 10, 16, 20], [13, 7, 4, 7], [25, 13, 23, 19]]
# Melakukan crossover...
# Crossover antara [13, 7, 4, 7] dan [13, 7, 4, 7] menghasilkan [13, 7, 4, 7] dan [13, 7, 4, 7]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 25 -> 3
# Mutasi pada kromosom 5 gen 3: 19 -> 7
# Generasi 0 Fitness Terbaik: 0.02631578947368421
#
# Generasi 1:
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [3, 13, 23, 7] -> Fitness: 0.01031
# Evaluasi fitness: [12, 10, 16, 20] -> Fitness: 0.00763
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [3, 13, 23, 7] -> Fitness: 0.01031
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[13, 7, 4, 7], [13, 7, 4, 7], [13, 7, 4, 7], [12, 10, 16, 20], [13, 7, 4, 7], [13, 7, 4, 7]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 3: 7 -> 29
# Mutasi pada kromosom 0 gen 2: 4 -> 0
# Generasi 1 Fitness Terbaik: 0.02631578947368421
#
# Generasi 2:
# Evaluasi fitness: [13, 7, 0, 29] -> Fitness: 0.00877
# Evaluasi fitness: [13, 7, 0, 29] -> Fitness: 0.00877
# Evaluasi fitness: [13, 7, 0, 29] -> Fitness: 0.00877
# Evaluasi fitness: [12, 10, 16, 20] -> Fitness: 0.00763
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [13, 7, 0, 29] -> Fitness: 0.00877
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[13, 7, 0, 29], [12, 10, 16, 20], [13, 7, 0, 29], [13, 7, 0, 29], [12, 10, 16, 20], [13, 7, 4, 7]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 1: 7 -> 30
# Mutasi pada kromosom 2 gen 2: 0 -> 16
# Generasi 2 Fitness Terbaik: 0.02631578947368421
#
# Generasi 3:
# Evaluasi fitness: [13, 30, 16, 29] -> Fitness: 0.00481
# Evaluasi fitness: [12, 10, 16, 20] -> Fitness: 0.00763
# Evaluasi fitness: [13, 30, 16, 29] -> Fitness: 0.00481
# Evaluasi fitness: [13, 30, 16, 29] -> Fitness: 0.00481
# Evaluasi fitness: [12, 10, 16, 20] -> Fitness: 0.00763
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[12, 10, 16, 20], [13, 7, 4, 7], [13, 7, 4, 7], [13, 7, 4, 7], [13, 30, 16, 29], [13, 30, 16, 29]]
# Melakukan crossover...
# Crossover antara [13, 30, 16, 29] dan [13, 30, 16, 29] menghasilkan [13, 30, 16, 29] dan [13, 30, 16, 29]
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 2: 16 -> 23
# Mutasi pada kromosom 0 gen 0: 12 -> 12
# Generasi 3 Fitness Terbaik: 0.02631578947368421
#
# Generasi 4:
# Evaluasi fitness: [12, 10, 16, 20] -> Fitness: 0.00763
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [13, 7, 4, 7] -> Fitness: 0.02632
# Evaluasi fitness: [13, 30, 23, 29] -> Fitness: 0.00437
# Evaluasi fitness: [13, 30, 16, 29] -> Fitness: 0.00481
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[13, 7, 4, 7], [13, 7, 4, 7], [13, 7, 4, 7], [13, 7, 4, 7], [13, 7, 4, 7], [13, 7, 4, 7]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 13 -> 24
# Mutasi pada kromosom 0 gen 1: 7 -> 23
# Generasi 4 Fitness Terbaik: 0.02631578947368421
#
# Generasi 5:
# Evaluasi fitness: [24, 23, 4, 7] -> Fitness: 0.01235
# Evaluasi fitness: [24, 23, 4, 7] -> Fitness: 0.01235
# Evaluasi fitness: [24, 23, 4, 7] -> Fitness: 0.01235
# Evaluasi fitness: [24, 23, 4, 7] -> Fitness: 0.01235
# Evaluasi fitness: [24, 23, 4, 7] -> Fitness: 0.01235
# Evaluasi fitness: [24, 23, 4, 7] -> Fitness: 0.01235
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 23, 4, 7], [24, 23, 4, 7], [24, 23, 4, 7], [24, 23, 4, 7], [24, 23, 4, 7], [24, 23, 4, 7]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 3: 7 -> 12
# Mutasi pada kromosom 4 gen 1: 23 -> 5
# Generasi 5 Fitness Terbaik: 0.012345679012345678
#
# Generasi 6:
# Evaluasi fitness: [24, 5, 4, 12] -> Fitness: 0.01538
# Evaluasi fitness: [24, 5, 4, 12] -> Fitness: 0.01538
# Evaluasi fitness: [24, 5, 4, 12] -> Fitness: 0.01538
# Evaluasi fitness: [24, 5, 4, 12] -> Fitness: 0.01538
# Evaluasi fitness: [24, 5, 4, 12] -> Fitness: 0.01538
# Evaluasi fitness: [24, 5, 4, 12] -> Fitness: 0.01538
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 5, 4, 12], [24, 5, 4, 12], [24, 5, 4, 12], [24, 5, 4, 12], [24, 5, 4, 12], [24, 5, 4, 12]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 3: 12 -> 23
# Mutasi pada kromosom 0 gen 2: 4 -> 10
# Generasi 6 Fitness Terbaik: 0.015384615384615385
#
# Generasi 7:
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 5, 10, 23], [24, 5, 10, 23], [24, 5, 10, 23], [24, 5, 10, 23], [24, 5, 10, 23], [24, 5, 10, 23]]
# Melakukan crossover...
# Crossover antara [24, 5, 10, 23] dan [24, 5, 10, 23] menghasilkan [24, 5, 10, 23] dan [24, 5, 10, 23]
# Crossover antara [24, 5, 10, 23] dan [24, 5, 10, 23] menghasilkan [24, 5, 10, 23] dan [24, 5, 10, 23]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 3: 23 -> 16
# Mutasi pada kromosom 2 gen 3: 23 -> 20
# Generasi 7 Fitness Terbaik: 0.007874015748031496
#
# Generasi 8:
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 16] -> Fitness: 0.01010
# Evaluasi fitness: [24, 5, 10, 20] -> Fitness: 0.00870
# Evaluasi fitness: [24, 5, 10, 20] -> Fitness: 0.00870
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 5, 10, 20], [24, 5, 10, 23], [24, 5, 10, 20], [24, 5, 10, 16], [24, 5, 10, 16], [24, 5, 10, 20]]
# Melakukan crossover...
# Crossover antara [24, 5, 10, 20] dan [24, 5, 10, 23] menghasilkan [24, 5, 10, 23] dan [24, 5, 10, 20]
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 1: 5 -> 1
# Mutasi pada kromosom 1 gen 3: 20 -> 2
# Generasi 8 Fitness Terbaik: 0.010101010101010102
#
# Generasi 9:
# Evaluasi fitness: [24, 5, 10, 23] -> Fitness: 0.00787
# Evaluasi fitness: [24, 5, 10, 2] -> Fitness: 0.02326
# Evaluasi fitness: [24, 1, 10, 20] -> Fitness: 0.00935
# Evaluasi fitness: [24, 5, 10, 16] -> Fitness: 0.01010
# Evaluasi fitness: [24, 5, 10, 16] -> Fitness: 0.01010
# Evaluasi fitness: [24, 1, 10, 20] -> Fitness: 0.00935
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 5, 10, 16], [24, 5, 10, 2], [24, 5, 10, 16], [24, 5, 10, 16], [24, 1, 10, 20], [24, 1, 10, 20]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 3: 16 -> 3
# Mutasi pada kromosom 3 gen 0: 24 -> 18
# Generasi 9 Fitness Terbaik: 0.023255813953488372
#
# Generasi 10:
# Evaluasi fitness: [18, 5, 10, 3] -> Fitness: 0.02439
# Evaluasi fitness: [24, 5, 10, 2] -> Fitness: 0.02326
# Evaluasi fitness: [18, 5, 10, 3] -> Fitness: 0.02439
# Evaluasi fitness: [18, 5, 10, 3] -> Fitness: 0.02439
# Evaluasi fitness: [24, 1, 10, 20] -> Fitness: 0.00935
# Evaluasi fitness: [24, 1, 10, 20] -> Fitness: 0.00935
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[18, 5, 10, 3], [24, 5, 10, 2], [18, 5, 10, 3], [18, 5, 10, 3], [24, 5, 10, 2], [18, 5, 10, 3]]
# Melakukan crossover...
# Crossover antara [18, 5, 10, 3] dan [18, 5, 10, 3] menghasilkan [18, 5, 10, 3] dan [18, 5, 10, 3]
# Crossover antara [24, 5, 10, 2] dan [18, 5, 10, 3] menghasilkan [24, 5, 10, 3] dan [18, 5, 10, 2]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 2: 10 -> 27
# Mutasi pada kromosom 2 gen 2: 10 -> 10
# Generasi 10 Fitness Terbaik: 0.024390243902439025
#
# Generasi 11:
# Evaluasi fitness: [18, 5, 10, 3] -> Fitness: 0.02439
# Evaluasi fitness: [24, 5, 10, 2] -> Fitness: 0.02326
# Evaluasi fitness: [18, 5, 10, 3] -> Fitness: 0.02439
# Evaluasi fitness: [18, 5, 27, 3] -> Fitness: 0.01087
# Evaluasi fitness: [24, 5, 10, 3] -> Fitness: 0.02128
# Evaluasi fitness: [18, 5, 10, 2] -> Fitness: 0.02703
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 5, 10, 3], [24, 5, 10, 3], [24, 5, 10, 3], [18, 5, 10, 3], [24, 5, 10, 3], [24, 5, 10, 2]]
# Melakukan crossover...
# Crossover antara [24, 5, 10, 3] dan [18, 5, 10, 3] menghasilkan [24, 5, 10, 3] dan [18, 5, 10, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 0: 24 -> 19
# Mutasi pada kromosom 1 gen 0: 19 -> 10
# Generasi 11 Fitness Terbaik: 0.02702702702702703
#
# Generasi 12:
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [24, 5, 10, 3] -> Fitness: 0.02128
# Evaluasi fitness: [18, 5, 10, 3] -> Fitness: 0.02439
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [24, 5, 10, 2] -> Fitness: 0.02326
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 5, 10, 2], [24, 5, 10, 3], [10, 5, 10, 3], [10, 5, 10, 3], [10, 5, 10, 3], [18, 5, 10, 3]]
# Melakukan crossover...
# Crossover antara [24, 5, 10, 2] dan [24, 5, 10, 3] menghasilkan [24, 5, 10, 3] dan [24, 5, 10, 2]
# Crossover antara [10, 5, 10, 3] dan [18, 5, 10, 3] menghasilkan [10, 5, 10, 3] dan [18, 5, 10, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 0: 18 -> 22
# Mutasi pada kromosom 5 gen 2: 10 -> 15
# Generasi 12 Fitness Terbaik: 0.030303030303030304
#
# Generasi 13:
# Evaluasi fitness: [24, 5, 10, 3] -> Fitness: 0.02128
# Evaluasi fitness: [24, 5, 10, 2] -> Fitness: 0.02326
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [22, 5, 15, 3] -> Fitness: 0.01667
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[10, 5, 10, 3], [24, 5, 10, 3], [10, 5, 10, 3], [10, 5, 10, 3], [10, 5, 10, 3], [10, 5, 10, 3]]
# Melakukan crossover...
# Crossover antara [10, 5, 10, 3] dan [24, 5, 10, 3] menghasilkan [10, 5, 10, 3] dan [24, 5, 10, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 3: 3 -> 10
# Mutasi pada kromosom 2 gen 2: 10 -> 28
# Generasi 13 Fitness Terbaik: 0.030303030303030304
#
# Generasi 14:
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [24, 5, 10, 3] -> Fitness: 0.02128
# Evaluasi fitness: [10, 5, 28, 10] -> Fitness: 0.00870
# Evaluasi fitness: [10, 5, 28, 10] -> Fitness: 0.00870
# Evaluasi fitness: [10, 5, 28, 10] -> Fitness: 0.00870
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[10, 5, 10, 3], [10, 5, 10, 3], [24, 5, 10, 3], [10, 5, 10, 3], [10, 5, 28, 10], [24, 5, 10, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 0: 10 -> 30
# Mutasi pada kromosom 4 gen 0: 10 -> 2
# Generasi 14 Fitness Terbaik: 0.030303030303030304
#
# Generasi 15:
# Evaluasi fitness: [30, 5, 10, 3] -> Fitness: 0.01887
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [24, 5, 10, 3] -> Fitness: 0.02128
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [2, 5, 28, 10] -> Fitness: 0.00935
# Evaluasi fitness: [24, 5, 10, 3] -> Fitness: 0.02128
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 5, 10, 3], [24, 5, 10, 3], [10, 5, 10, 3], [24, 5, 10, 3], [30, 5, 10, 3], [24, 5, 10, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 1: 5 -> 3
# Mutasi pada kromosom 3 gen 2: 10 -> 3
# Generasi 15 Fitness Terbaik: 0.030303030303030304
#
# Generasi 16:
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [10, 5, 10, 3] -> Fitness: 0.03030
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [30, 5, 10, 3] -> Fitness: 0.01887
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3]]
# Melakukan crossover...
# Crossover antara [24, 3, 3, 3] dan [24, 3, 3, 3] menghasilkan [24, 3, 3, 3] dan [24, 3, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 1: 3 -> 4
# Mutasi pada kromosom 5 gen 0: 24 -> 27
# Generasi 16 Fitness Terbaik: 0.045454545454545456
#
# Generasi 17:
# Evaluasi fitness: [27, 4, 3, 3] -> Fitness: 0.03704
# Evaluasi fitness: [27, 4, 3, 3] -> Fitness: 0.03704
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [27, 4, 3, 3] -> Fitness: 0.03704
# Evaluasi fitness: [27, 4, 3, 3] -> Fitness: 0.03704
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3], [27, 4, 3, 3], [24, 3, 3, 3], [27, 4, 3, 3]]
# Melakukan crossover...
# Crossover antara [24, 3, 3, 3] dan [24, 3, 3, 3] menghasilkan [24, 3, 3, 3] dan [24, 3, 3, 3]
# Crossover antara [24, 3, 3, 3] dan [27, 4, 3, 3] menghasilkan [24, 3, 3, 3] dan [27, 4, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 2: 3 -> 2
# Mutasi pada kromosom 1 gen 1: 3 -> 17
# Generasi 17 Fitness Terbaik: 0.045454545454545456
#
# Generasi 18:
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [24, 17, 3, 3] -> Fitness: 0.02000
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [27, 4, 2, 3] -> Fitness: 0.04167
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [27, 4, 3, 3] -> Fitness: 0.03704
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 17, 3, 3], [27, 4, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3], [27, 4, 2, 3], [27, 4, 3, 3]]
# Melakukan crossover...
# Crossover antara [27, 4, 2, 3] dan [27, 4, 3, 3] menghasilkan [27, 4, 3, 3] dan [27, 4, 2, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 2: 3 -> 23
# Mutasi pada kromosom 0 gen 1: 17 -> 28
# Generasi 18 Fitness Terbaik: 0.045454545454545456
#
# Generasi 19:
# Evaluasi fitness: [24, 28, 3, 3] -> Fitness: 0.01389
# Evaluasi fitness: [27, 4, 23, 3] -> Fitness: 0.01149
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [27, 4, 3, 3] -> Fitness: 0.03704
# Evaluasi fitness: [27, 4, 2, 3] -> Fitness: 0.04167
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3], [27, 4, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 2: 3 -> 19
# Mutasi pada kromosom 0 gen 0: 24 -> 2
# Generasi 19 Fitness Terbaik: 0.045454545454545456
#
# Generasi 20:
# Evaluasi fitness: [2, 3, 19, 3] -> Fitness: 0.02083
# Evaluasi fitness: [2, 3, 19, 3] -> Fitness: 0.02083
# Evaluasi fitness: [2, 3, 19, 3] -> Fitness: 0.02083
# Evaluasi fitness: [27, 4, 3, 3] -> Fitness: 0.03704
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [2, 3, 19, 3] -> Fitness: 0.02083
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 3, 3, 3], [2, 3, 19, 3], [2, 3, 19, 3], [2, 3, 19, 3], [2, 3, 19, 3], [24, 3, 3, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 0: 2 -> 25
# Mutasi pada kromosom 4 gen 1: 3 -> 3
# Generasi 20 Fitness Terbaik: 0.045454545454545456
#
# Generasi 21:
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [25, 3, 19, 3] -> Fitness: 0.01408
# Evaluasi fitness: [25, 3, 19, 3] -> Fitness: 0.01408
# Evaluasi fitness: [25, 3, 19, 3] -> Fitness: 0.01408
# Evaluasi fitness: [25, 3, 19, 3] -> Fitness: 0.01408
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 3, 3, 3], [24, 3, 3, 3], [25, 3, 19, 3], [24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3]]
# Melakukan crossover...
# Crossover antara [25, 3, 19, 3] dan [24, 3, 3, 3] menghasilkan [25, 3, 3, 3] dan [24, 3, 19, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 2: 3 -> 2
# Mutasi pada kromosom 4 gen 2: 2 -> 21
# Generasi 21 Fitness Terbaik: 0.045454545454545456
#
# Generasi 22:
# Evaluasi fitness: [24, 3, 21, 3] -> Fitness: 0.01316
# Evaluasi fitness: [24, 3, 21, 3] -> Fitness: 0.01316
# Evaluasi fitness: [25, 3, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [24, 3, 19, 3] -> Fitness: 0.01429
# Evaluasi fitness: [24, 3, 21, 3] -> Fitness: 0.01316
# Evaluasi fitness: [24, 3, 21, 3] -> Fitness: 0.01316
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[25, 3, 3, 3], [24, 3, 21, 3], [24, 3, 21, 3], [24, 3, 21, 3], [24, 3, 21, 3], [25, 3, 3, 3]]
# Melakukan crossover...
# Crossover antara [25, 3, 3, 3] dan [24, 3, 21, 3] menghasilkan [25, 3, 21, 3] dan [24, 3, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 2: 3 -> 24
# Mutasi pada kromosom 0 gen 1: 3 -> 7
# Generasi 22 Fitness Terbaik: 0.043478260869565216
#
# Generasi 23:
# Evaluasi fitness: [25, 7, 21, 3] -> Fitness: 0.01176
# Evaluasi fitness: [24, 3, 24, 3] -> Fitness: 0.01176
# Evaluasi fitness: [24, 3, 21, 3] -> Fitness: 0.01316
# Evaluasi fitness: [24, 3, 21, 3] -> Fitness: 0.01316
# Evaluasi fitness: [24, 3, 21, 3] -> Fitness: 0.01316
# Evaluasi fitness: [25, 3, 3, 3] -> Fitness: 0.04348
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[25, 3, 3, 3], [25, 3, 3, 3], [25, 3, 3, 3], [24, 3, 21, 3], [25, 3, 3, 3], [24, 3, 21, 3]]
# Melakukan crossover...
# Crossover antara [25, 3, 3, 3] dan [25, 3, 3, 3] menghasilkan [25, 3, 3, 3] dan [25, 3, 3, 3]
# Crossover antara [25, 3, 3, 3] dan [24, 3, 21, 3] menghasilkan [25, 3, 21, 3] dan [24, 3, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 25 -> 5
# Mutasi pada kromosom 3 gen 3: 3 -> 17
# Generasi 23 Fitness Terbaik: 0.043478260869565216
#
# Generasi 24:
# Evaluasi fitness: [25, 3, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [25, 3, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [5, 3, 3, 3] -> Fitness: 0.33333
# Evaluasi fitness: [24, 3, 21, 17] -> Fitness: 0.00758
# Evaluasi fitness: [25, 3, 21, 3] -> Fitness: 0.01299
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 3, 3, 3], [25, 3, 3, 3], [5, 3, 3, 3], [5, 3, 3, 3], [5, 3, 3, 3], [24, 3, 3, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 1: 3 -> 24
# Mutasi pada kromosom 1 gen 2: 3 -> 6
# Generasi 24 Fitness Terbaik: 0.3333333333333333
#
# Generasi 25:
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [25, 3, 6, 3] -> Fitness: 0.03125
# Evaluasi fitness: [5, 24, 3, 3] -> Fitness: 0.02222
# Evaluasi fitness: [5, 24, 3, 3] -> Fitness: 0.02222
# Evaluasi fitness: [5, 24, 3, 3] -> Fitness: 0.02222
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[5, 24, 3, 3], [5, 24, 3, 3], [24, 3, 3, 3], [5, 24, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3]]
# Melakukan crossover...
# Crossover antara [24, 3, 3, 3] dan [5, 24, 3, 3] menghasilkan [24, 3, 3, 3] dan [5, 24, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 2: 3 -> 26
# Mutasi pada kromosom 1 gen 3: 3 -> 11
# Generasi 25 Fitness Terbaik: 0.045454545454545456
#
# Generasi 26:
# Evaluasi fitness: [5, 24, 3, 11] -> Fitness: 0.01299
# Evaluasi fitness: [5, 24, 3, 11] -> Fitness: 0.01299
# Evaluasi fitness: [24, 3, 26, 3] -> Fitness: 0.01099
# Evaluasi fitness: [5, 24, 3, 3] -> Fitness: 0.02222
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Evaluasi fitness: [24, 3, 3, 3] -> Fitness: 0.04545
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[5, 24, 3, 11], [24, 3, 3, 3], [5, 24, 3, 11], [24, 3, 3, 3], [24, 3, 3, 3], [24, 3, 3, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 1: 3 -> 2
# Mutasi pada kromosom 3 gen 1: 2 -> 13
# Generasi 26 Fitness Terbaik: 0.045454545454545456
#
# Generasi 27:
# Evaluasi fitness: [5, 24, 3, 11] -> Fitness: 0.01299
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [5, 24, 3, 11] -> Fitness: 0.01299
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3]]
# Melakukan crossover...
# Crossover antara [24, 13, 3, 3] dan [24, 13, 3, 3] menghasilkan [24, 13, 3, 3] dan [24, 13, 3, 3]
# Crossover antara [24, 13, 3, 3] dan [24, 13, 3, 3] menghasilkan [24, 13, 3, 3] dan [24, 13, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 3: 3 -> 29
# Mutasi pada kromosom 1 gen 3: 29 -> 28
# Generasi 27 Fitness Terbaik: 0.023809523809523808
#
# Generasi 28:
# Evaluasi fitness: [24, 13, 3, 28] -> Fitness: 0.00704
# Evaluasi fitness: [24, 13, 3, 28] -> Fitness: 0.00704
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3], [24, 13, 3, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 2: 3 -> 4
# Mutasi pada kromosom 5 gen 1: 13 -> 2
# Generasi 28 Fitness Terbaik: 0.023809523809523808
#
# Generasi 29:
# Evaluasi fitness: [24, 2, 3, 3] -> Fitness: 0.05000
# Evaluasi fitness: [24, 13, 4, 3] -> Fitness: 0.02222
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [24, 13, 4, 3] -> Fitness: 0.02222
# Evaluasi fitness: [24, 13, 4, 3] -> Fitness: 0.02222
# Evaluasi fitness: [24, 2, 3, 3] -> Fitness: 0.05000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 2, 3, 3], [24, 13, 4, 3], [24, 13, 3, 3], [24, 13, 4, 3], [24, 2, 3, 3], [24, 13, 4, 3]]
# Melakukan crossover...
# Crossover antara [24, 2, 3, 3] dan [24, 13, 4, 3] menghasilkan [24, 2, 4, 3] dan [24, 13, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 3: 3 -> 29
# Mutasi pada kromosom 5 gen 0: 24 -> 3
# Generasi 29 Fitness Terbaik: 0.05
#
# Generasi 30:
# Evaluasi fitness: [24, 2, 4, 3] -> Fitness: 0.04348
# Evaluasi fitness: [24, 13, 3, 29] -> Fitness: 0.00685
# Evaluasi fitness: [24, 13, 3, 3] -> Fitness: 0.02381
# Evaluasi fitness: [3, 13, 4, 3] -> Fitness: 0.04167
# Evaluasi fitness: [24, 2, 3, 3] -> Fitness: 0.05000
# Evaluasi fitness: [3, 13, 4, 3] -> Fitness: 0.04167
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[3, 13, 4, 3], [3, 13, 4, 3], [3, 13, 4, 3], [24, 2, 3, 3], [3, 13, 4, 3], [3, 13, 4, 3]]
# Melakukan crossover...
# Crossover antara [3, 13, 4, 3] dan [24, 2, 3, 3] menghasilkan [3, 13, 3, 3] dan [24, 2, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 2: 4 -> 28
# Mutasi pada kromosom 5 gen 1: 13 -> 2
# Generasi 30 Fitness Terbaik: 0.05
#
# Generasi 31:
# Evaluasi fitness: [3, 2, 28, 3] -> Fitness: 0.01351
# Evaluasi fitness: [3, 2, 28, 3] -> Fitness: 0.01351
# Evaluasi fitness: [3, 13, 3, 3] -> Fitness: 0.04762
# Evaluasi fitness: [24, 2, 4, 3] -> Fitness: 0.04348
# Evaluasi fitness: [3, 2, 28, 3] -> Fitness: 0.01351
# Evaluasi fitness: [3, 2, 28, 3] -> Fitness: 0.01351
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[24, 2, 4, 3], [24, 2, 4, 3], [24, 2, 4, 3], [24, 2, 4, 3], [3, 2, 28, 3], [24, 2, 4, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 3: 3 -> 19
# Mutasi pada kromosom 2 gen 0: 24 -> 19
# Generasi 31 Fitness Terbaik: 0.047619047619047616
#
# Generasi 32:
# Evaluasi fitness: [19, 2, 4, 3] -> Fitness: 0.05556
# Evaluasi fitness: [19, 2, 4, 3] -> Fitness: 0.05556
# Evaluasi fitness: [19, 2, 4, 3] -> Fitness: 0.05556
# Evaluasi fitness: [19, 2, 4, 3] -> Fitness: 0.05556
# Evaluasi fitness: [3, 2, 28, 19] -> Fitness: 0.00725
# Evaluasi fitness: [19, 2, 4, 3] -> Fitness: 0.05556
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[19, 2, 4, 3], [19, 2, 4, 3], [19, 2, 4, 3], [19, 2, 4, 3], [19, 2, 4, 3], [19, 2, 4, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 0: 19 -> 25
# Mutasi pada kromosom 1 gen 1: 2 -> 27
# Generasi 32 Fitness Terbaik: 0.05555555555555555
#
# Generasi 33:
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[25, 27, 4, 3], [25, 27, 4, 3], [25, 27, 4, 3], [25, 27, 4, 3], [25, 27, 4, 3], [25, 27, 4, 3]]
# Melakukan crossover...
# Crossover antara [25, 27, 4, 3] dan [25, 27, 4, 3] menghasilkan [25, 27, 4, 3] dan [25, 27, 4, 3]
# Crossover antara [25, 27, 4, 3] dan [25, 27, 4, 3] menghasilkan [25, 27, 4, 3] dan [25, 27, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 3: 3 -> 4
# Mutasi pada kromosom 0 gen 3: 3 -> 30
# Generasi 33 Fitness Terbaik: 0.013513513513513514
#
# Generasi 34:
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 4] -> Fitness: 0.01282
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[25, 27, 4, 3], [25, 27, 4, 30], [25, 27, 4, 3], [25, 27, 4, 3], [25, 27, 4, 30], [25, 27, 4, 30]]
# Melakukan crossover...
# Crossover antara [25, 27, 4, 3] dan [25, 27, 4, 3] menghasilkan [25, 27, 4, 3] dan [25, 27, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 3: 3 -> 19
# Mutasi pada kromosom 3 gen 3: 3 -> 2
# Generasi 34 Fitness Terbaik: 0.013513513513513514
#
# Generasi 35:
# Evaluasi fitness: [25, 27, 4, 19] -> Fitness: 0.00725
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 4, 2] -> Fitness: 0.01429
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[25, 27, 4, 30], [25, 27, 4, 2], [25, 27, 4, 3], [25, 27, 4, 3], [25, 27, 4, 30], [25, 27, 4, 2]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 25 -> 17
# Mutasi pada kromosom 5 gen 3: 2 -> 24
# Generasi 35 Fitness Terbaik: 0.014285714285714285
#
# Generasi 36:
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 4, 24] -> Fitness: 0.00633
# Evaluasi fitness: [17, 27, 4, 3] -> Fitness: 0.01515
# Evaluasi fitness: [17, 27, 4, 3] -> Fitness: 0.01515
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 4, 24] -> Fitness: 0.00633
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[25, 27, 4, 30], [25, 27, 4, 30], [17, 27, 4, 3], [25, 27, 4, 30], [25, 27, 4, 30], [17, 27, 4, 3]]
# Melakukan crossover...
# Crossover antara [25, 27, 4, 30] dan [25, 27, 4, 30] menghasilkan [25, 27, 4, 30] dan [25, 27, 4, 30]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 17 -> 13
# Mutasi pada kromosom 1 gen 2: 4 -> 29
# Generasi 36 Fitness Terbaik: 0.015151515151515152
#
# Generasi 37:
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 29, 30] -> Fitness: 0.00389
# Evaluasi fitness: [13, 27, 4, 3] -> Fitness: 0.01613
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [25, 27, 4, 30] -> Fitness: 0.00549
# Evaluasi fitness: [13, 27, 4, 3] -> Fitness: 0.01613
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[13, 27, 4, 3], [25, 27, 4, 30], [25, 27, 4, 30], [13, 27, 4, 3], [13, 27, 4, 3], [13, 27, 4, 3]]
# Melakukan crossover...
# Crossover antara [13, 27, 4, 3] dan [25, 27, 4, 30] menghasilkan [13, 27, 4, 30] dan [25, 27, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 2: 4 -> 13
# Mutasi pada kromosom 5 gen 1: 27 -> 6
# Generasi 37 Fitness Terbaik: 0.016129032258064516
#
# Generasi 38:
# Evaluasi fitness: [13, 27, 4, 30] -> Fitness: 0.00588
# Evaluasi fitness: [25, 27, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [25, 27, 13, 30] -> Fitness: 0.00478
# Evaluasi fitness: [13, 6, 4, 3] -> Fitness: 0.05000
# Evaluasi fitness: [13, 6, 4, 3] -> Fitness: 0.05000
# Evaluasi fitness: [13, 6, 4, 3] -> Fitness: 0.05000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[13, 6, 4, 3], [13, 6, 4, 3], [13, 6, 4, 3], [13, 6, 4, 3], [13, 6, 4, 3], [13, 6, 4, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 0: 13 -> 25
# Mutasi pada kromosom 5 gen 1: 6 -> 13
# Generasi 38 Fitness Terbaik: 0.05
#
# Generasi 39:
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[25, 13, 4, 3], [25, 13, 4, 3], [25, 13, 4, 3], [25, 13, 4, 3], [25, 13, 4, 3], [25, 13, 4, 3]]
# Melakukan crossover...
# Crossover antara [25, 13, 4, 3] dan [25, 13, 4, 3] menghasilkan [25, 13, 4, 3] dan [25, 13, 4, 3]
# Crossover antara [25, 13, 4, 3] dan [25, 13, 4, 3] menghasilkan [25, 13, 4, 3] dan [25, 13, 4, 3]
# Crossover antara [25, 13, 4, 3] dan [25, 13, 4, 3] menghasilkan [25, 13, 4, 3] dan [25, 13, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 25 -> 23
# Mutasi pada kromosom 3 gen 0: 25 -> 14
# Generasi 39 Fitness Terbaik: 0.021739130434782608
#
# Generasi 40:
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [23, 13, 4, 3] -> Fitness: 0.02273
# Evaluasi fitness: [14, 13, 4, 3] -> Fitness: 0.02857
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[14, 13, 4, 3], [14, 13, 4, 3], [23, 13, 4, 3], [23, 13, 4, 3], [25, 13, 4, 3], [25, 13, 4, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 1: 13 -> 0
# Mutasi pada kromosom 0 gen 1: 13 -> 28
# Generasi 40 Fitness Terbaik: 0.02857142857142857
#
# Generasi 41:
# Evaluasi fitness: [14, 28, 4, 3] -> Fitness: 0.01538
# Evaluasi fitness: [14, 28, 4, 3] -> Fitness: 0.01538
# Evaluasi fitness: [23, 13, 4, 3] -> Fitness: 0.02273
# Evaluasi fitness: [23, 13, 4, 3] -> Fitness: 0.02273
# Evaluasi fitness: [25, 0, 4, 3] -> Fitness: 0.05000
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[14, 28, 4, 3], [25, 13, 4, 3], [23, 13, 4, 3], [25, 13, 4, 3], [25, 0, 4, 3], [23, 13, 4, 3]]
# Melakukan crossover...
# Crossover antara [23, 13, 4, 3] dan [25, 13, 4, 3] menghasilkan [23, 13, 4, 3] dan [25, 13, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 3: 3 -> 21
# Mutasi pada kromosom 5 gen 1: 13 -> 6
# Generasi 41 Fitness Terbaik: 0.05
#
# Generasi 42:
# Evaluasi fitness: [14, 28, 4, 3] -> Fitness: 0.01538
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [23, 13, 4, 3] -> Fitness: 0.02273
# Evaluasi fitness: [25, 13, 4, 21] -> Fitness: 0.00847
# Evaluasi fitness: [25, 0, 4, 3] -> Fitness: 0.05000
# Evaluasi fitness: [23, 6, 4, 3] -> Fitness: 0.03333
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[14, 28, 4, 3], [23, 6, 4, 3], [23, 13, 4, 3], [25, 0, 4, 3], [25, 13, 4, 3], [23, 13, 4, 3]]
# Melakukan crossover...
# Crossover antara [14, 28, 4, 3] dan [23, 6, 4, 3] menghasilkan [14, 6, 4, 3] dan [23, 28, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 23 -> 11
# Mutasi pada kromosom 3 gen 0: 25 -> 19
# Generasi 42 Fitness Terbaik: 0.05
#
# Generasi 43:
# Evaluasi fitness: [14, 6, 4, 3] -> Fitness: 0.04762
# Evaluasi fitness: [23, 28, 4, 3] -> Fitness: 0.01351
# Evaluasi fitness: [11, 13, 4, 3] -> Fitness: 0.03125
# Evaluasi fitness: [19, 0, 4, 3] -> Fitness: 0.07143
# Evaluasi fitness: [25, 13, 4, 3] -> Fitness: 0.02174
# Evaluasi fitness: [11, 13, 4, 3] -> Fitness: 0.03125
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[11, 13, 4, 3], [14, 6, 4, 3], [19, 0, 4, 3], [19, 0, 4, 3], [19, 0, 4, 3], [19, 0, 4, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 0: 19 -> 0
# Mutasi pada kromosom 5 gen 0: 0 -> 8
# Generasi 43 Fitness Terbaik: 0.07142857142857142
#
# Generasi 44:
# Evaluasi fitness: [11, 13, 4, 3] -> Fitness: 0.03125
# Evaluasi fitness: [14, 6, 4, 3] -> Fitness: 0.04762
# Evaluasi fitness: [8, 0, 4, 3] -> Fitness: 0.33333
# Evaluasi fitness: [8, 0, 4, 3] -> Fitness: 0.33333
# Evaluasi fitness: [8, 0, 4, 3] -> Fitness: 0.33333
# Evaluasi fitness: [8, 0, 4, 3] -> Fitness: 0.33333
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[8, 0, 4, 3], [8, 0, 4, 3], [8, 0, 4, 3], [8, 0, 4, 3], [8, 0, 4, 3], [8, 0, 4, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 1: 0 -> 26
# Mutasi pada kromosom 5 gen 0: 8 -> 29
# Generasi 44 Fitness Terbaik: 0.3333333333333333
#
# Generasi 45:
# Evaluasi fitness: [29, 26, 4, 3] -> Fitness: 0.01316
# Evaluasi fitness: [29, 26, 4, 3] -> Fitness: 0.01316
# Evaluasi fitness: [29, 26, 4, 3] -> Fitness: 0.01316
# Evaluasi fitness: [29, 26, 4, 3] -> Fitness: 0.01316
# Evaluasi fitness: [29, 26, 4, 3] -> Fitness: 0.01316
# Evaluasi fitness: [29, 26, 4, 3] -> Fitness: 0.01316
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[29, 26, 4, 3], [29, 26, 4, 3], [29, 26, 4, 3], [29, 26, 4, 3], [29, 26, 4, 3], [29, 26, 4, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 2: 4 -> 30
# Mutasi pada kromosom 0 gen 0: 29 -> 30
# Generasi 45 Fitness Terbaik: 0.013157894736842105
#
# Generasi 46:
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[30, 26, 30, 3], [30, 26, 30, 3], [30, 26, 30, 3], [30, 26, 30, 3], [30, 26, 30, 3], [30, 26, 30, 3]]
# Melakukan crossover...
# Crossover antara [30, 26, 30, 3] dan [30, 26, 30, 3] menghasilkan [30, 26, 30, 3] dan [30, 26, 30, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 2: 30 -> 7
# Mutasi pada kromosom 4 gen 0: 30 -> 1
# Generasi 46 Fitness Terbaik: 0.0064516129032258064
#
# Generasi 47:
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [30, 26, 7, 3] -> Fitness: 0.01163
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[1, 26, 30, 3], [1, 26, 30, 3], [30, 26, 7, 3], [30, 26, 30, 3], [1, 26, 30, 3], [1, 26, 30, 3]]
# Melakukan crossover...
# Crossover antara [1, 26, 30, 3] dan [1, 26, 30, 3] menghasilkan [1, 26, 30, 3] dan [1, 26, 30, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 1: 26 -> 10
# Mutasi pada kromosom 0 gen 3: 3 -> 26
# Generasi 47 Fitness Terbaik: 0.011627906976744186
#
# Generasi 48:
# Evaluasi fitness: [1, 26, 30, 26] -> Fitness: 0.00459
# Evaluasi fitness: [1, 10, 30, 3] -> Fitness: 0.01064
# Evaluasi fitness: [30, 26, 7, 3] -> Fitness: 0.01163
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[1, 10, 30, 3], [30, 26, 7, 3], [1, 10, 30, 3], [30, 26, 30, 3], [1, 26, 30, 3], [1, 26, 30, 3]]
# Melakukan crossover...
# Crossover antara [1, 26, 30, 3] dan [1, 26, 30, 3] menghasilkan [1, 26, 30, 3] dan [1, 26, 30, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 1 -> 27
# Mutasi pada kromosom 5 gen 2: 30 -> 28
# Generasi 48 Fitness Terbaik: 0.011627906976744186
#
# Generasi 49:
# Evaluasi fitness: [27, 10, 30, 3] -> Fitness: 0.00833
# Evaluasi fitness: [30, 26, 7, 3] -> Fitness: 0.01163
# Evaluasi fitness: [27, 10, 30, 3] -> Fitness: 0.00833
# Evaluasi fitness: [30, 26, 30, 3] -> Fitness: 0.00645
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Evaluasi fitness: [1, 26, 28, 3] -> Fitness: 0.00833
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[27, 10, 30, 3], [27, 10, 30, 3], [1, 26, 28, 3], [27, 10, 30, 3], [1, 26, 30, 3], [27, 10, 30, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 0: 27 -> 6
# Mutasi pada kromosom 1 gen 3: 3 -> 21
# Generasi 49 Fitness Terbaik: 0.011627906976744186
#
# Generasi 50:
# Evaluasi fitness: [6, 10, 30, 21] -> Fitness: 0.00585
# Evaluasi fitness: [6, 10, 30, 21] -> Fitness: 0.00585
# Evaluasi fitness: [1, 26, 28, 3] -> Fitness: 0.00833
# Evaluasi fitness: [6, 10, 30, 21] -> Fitness: 0.00585
# Evaluasi fitness: [1, 26, 30, 3] -> Fitness: 0.00794
# Evaluasi fitness: [6, 10, 30, 21] -> Fitness: 0.00585
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[6, 10, 30, 21], [6, 10, 30, 21], [6, 10, 30, 21], [6, 10, 30, 21], [6, 10, 30, 21], [6, 10, 30, 21]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 1: 10 -> 15
# Mutasi pada kromosom 4 gen 0: 6 -> 22
# Generasi 50 Fitness Terbaik: 0.008333333333333333
#
# Generasi 51:
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 15, 30, 21], [22, 15, 30, 21], [22, 15, 30, 21], [22, 15, 30, 21], [22, 15, 30, 21], [22, 15, 30, 21]]
# Melakukan crossover...
# Crossover antara [22, 15, 30, 21] dan [22, 15, 30, 21] menghasilkan [22, 15, 30, 21] dan [22, 15, 30, 21]
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 3: 21 -> 8
# Mutasi pada kromosom 2 gen 3: 8 -> 18
# Generasi 51 Fitness Terbaik: 0.005076142131979695
#
# Generasi 52:
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Evaluasi fitness: [22, 15, 30, 21] -> Fitness: 0.00508
# Evaluasi fitness: [22, 15, 30, 18] -> Fitness: 0.00541
# Evaluasi fitness: [22, 15, 30, 18] -> Fitness: 0.00541
# Evaluasi fitness: [22, 15, 30, 18] -> Fitness: 0.00541
# Evaluasi fitness: [22, 15, 30, 18] -> Fitness: 0.00541
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 15, 30, 21], [22, 15, 30, 18], [22, 15, 30, 21], [22, 15, 30, 21], [22, 15, 30, 18], [22, 15, 30, 21]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 2: 30 -> 19
# Mutasi pada kromosom 4 gen 3: 18 -> 28
# Generasi 52 Fitness Terbaik: 0.005405405405405406
#
# Generasi 53:
# Evaluasi fitness: [22, 15, 19, 21] -> Fitness: 0.00610
# Evaluasi fitness: [22, 15, 30, 28] -> Fitness: 0.00444
# Evaluasi fitness: [22, 15, 19, 21] -> Fitness: 0.00610
# Evaluasi fitness: [22, 15, 19, 21] -> Fitness: 0.00610
# Evaluasi fitness: [22, 15, 30, 28] -> Fitness: 0.00444
# Evaluasi fitness: [22, 15, 19, 21] -> Fitness: 0.00610
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 15, 19, 21], [22, 15, 19, 21], [22, 15, 19, 21], [22, 15, 19, 21], [22, 15, 19, 21], [22, 15, 19, 21]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 2: 19 -> 2
# Mutasi pada kromosom 0 gen 1: 15 -> 7
# Generasi 53 Fitness Terbaik: 0.006097560975609756
#
# Generasi 54:
# Evaluasi fitness: [22, 7, 2, 21] -> Fitness: 0.01031
# Evaluasi fitness: [22, 7, 2, 21] -> Fitness: 0.01031
# Evaluasi fitness: [22, 7, 2, 21] -> Fitness: 0.01031
# Evaluasi fitness: [22, 7, 2, 21] -> Fitness: 0.01031
# Evaluasi fitness: [22, 7, 2, 21] -> Fitness: 0.01031
# Evaluasi fitness: [22, 7, 2, 21] -> Fitness: 0.01031
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 7, 2, 21], [22, 7, 2, 21], [22, 7, 2, 21], [22, 7, 2, 21], [22, 7, 2, 21], [22, 7, 2, 21]]
# Melakukan crossover...
# Crossover antara [22, 7, 2, 21] dan [22, 7, 2, 21] menghasilkan [22, 7, 2, 21] dan [22, 7, 2, 21]
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 0: 22 -> 0
# Mutasi pada kromosom 3 gen 3: 21 -> 1
# Generasi 54 Fitness Terbaik: 0.010309278350515464
#
# Generasi 55:
# Evaluasi fitness: [22, 7, 2, 1] -> Fitness: 0.05882
# Evaluasi fitness: [22, 7, 2, 1] -> Fitness: 0.05882
# Evaluasi fitness: [22, 7, 2, 1] -> Fitness: 0.05882
# Evaluasi fitness: [22, 7, 2, 1] -> Fitness: 0.05882
# Evaluasi fitness: [22, 7, 2, 21] -> Fitness: 0.01031
# Evaluasi fitness: [0, 7, 2, 21] -> Fitness: 0.01333
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 7, 2, 1], [22, 7, 2, 1], [0, 7, 2, 21], [22, 7, 2, 1], [22, 7, 2, 1], [22, 7, 2, 1]]
# Melakukan crossover...
# Crossover antara [22, 7, 2, 1] dan [22, 7, 2, 1] menghasilkan [22, 7, 2, 1] dan [22, 7, 2, 1]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 1: 7 -> 25
# Mutasi pada kromosom 4 gen 2: 2 -> 1
# Generasi 55 Fitness Terbaik: 0.058823529411764705
#
# Generasi 56:
# Evaluasi fitness: [22, 25, 2, 1] -> Fitness: 0.01887
# Evaluasi fitness: [22, 25, 2, 1] -> Fitness: 0.01887
# Evaluasi fitness: [0, 7, 2, 21] -> Fitness: 0.01333
# Evaluasi fitness: [22, 25, 2, 1] -> Fitness: 0.01887
# Evaluasi fitness: [22, 7, 1, 1] -> Fitness: 0.07143
# Evaluasi fitness: [22, 7, 2, 1] -> Fitness: 0.05882
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 25, 2, 1], [22, 7, 1, 1], [0, 7, 2, 21], [0, 7, 2, 21], [22, 25, 2, 1], [22, 7, 2, 1]]
# Melakukan crossover...
# Crossover antara [0, 7, 2, 21] dan [0, 7, 2, 21] menghasilkan [0, 7, 2, 21] dan [0, 7, 2, 21]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 1: 7 -> 29
# Mutasi pada kromosom 4 gen 1: 25 -> 10
# Generasi 56 Fitness Terbaik: 0.07142857142857142
#
# Generasi 57:
# Evaluasi fitness: [22, 10, 2, 1] -> Fitness: 0.04348
# Evaluasi fitness: [22, 7, 1, 1] -> Fitness: 0.07143
# Evaluasi fitness: [0, 7, 2, 21] -> Fitness: 0.01333
# Evaluasi fitness: [0, 29, 2, 21] -> Fitness: 0.00840
# Evaluasi fitness: [22, 10, 2, 1] -> Fitness: 0.04348
# Evaluasi fitness: [22, 7, 2, 1] -> Fitness: 0.05882
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 10, 2, 1], [22, 10, 2, 1], [22, 7, 2, 1], [22, 7, 2, 1], [22, 10, 2, 1], [22, 7, 2, 1]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 0: 22 -> 5
# Mutasi pada kromosom 1 gen 3: 1 -> 16
# Generasi 57 Fitness Terbaik: 0.07142857142857142
#
# Generasi 58:
# Evaluasi fitness: [22, 10, 2, 16] -> Fitness: 0.01205
# Evaluasi fitness: [22, 10, 2, 16] -> Fitness: 0.01205
# Evaluasi fitness: [5, 7, 2, 1] -> Fitness: 0.50000
# Evaluasi fitness: [5, 7, 2, 1] -> Fitness: 0.50000
# Evaluasi fitness: [22, 10, 2, 16] -> Fitness: 0.01205
# Evaluasi fitness: [5, 7, 2, 1] -> Fitness: 0.50000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[22, 10, 2, 16], [5, 7, 2, 1], [5, 7, 2, 1], [5, 7, 2, 1], [5, 7, 2, 1], [5, 7, 2, 1]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 3: 1 -> 0
# Mutasi pada kromosom 2 gen 2: 2 -> 5
# Generasi 58 Fitness Terbaik: 0.5
#
# Generasi 59:
# Evaluasi fitness: [22, 10, 2, 16] -> Fitness: 0.01205
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0]]
# Melakukan crossover...
# Crossover antara [5, 7, 5, 0] dan [5, 7, 5, 0] menghasilkan [5, 7, 5, 0] dan [5, 7, 5, 0]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 2: 5 -> 19
# Mutasi pada kromosom 0 gen 2: 5 -> 12
# Generasi 59 Fitness Terbaik: 0.2
#
# Generasi 60:
# Evaluasi fitness: [5, 7, 12, 0] -> Fitness: 0.03846
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 19, 0] -> Fitness: 0.02128
# Evaluasi fitness: [5, 7, 19, 0] -> Fitness: 0.02128
# Evaluasi fitness: [5, 7, 19, 0] -> Fitness: 0.02128
# Evaluasi fitness: [5, 7, 19, 0] -> Fitness: 0.02128
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[5, 7, 19, 0], [5, 7, 5, 0], [5, 7, 19, 0], [5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 3: 0 -> 25
# Mutasi pada kromosom 0 gen 2: 19 -> 23
# Generasi 60 Fitness Terbaik: 0.2
#
# Generasi 61:
# Evaluasi fitness: [5, 7, 23, 25] -> Fitness: 0.00629
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 23, 25] -> Fitness: 0.00629
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Evaluasi fitness: [5, 7, 5, 0] -> Fitness: 0.20000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0], [5, 7, 5, 0]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 3: 0 -> 3
# Mutasi pada kromosom 0 gen 0: 5 -> 4
# Generasi 61 Fitness Terbaik: 0.2
#
# Generasi 62:
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3]]
# Melakukan crossover...
# Crossover antara [4, 7, 5, 3] dan [4, 7, 5, 3] menghasilkan [4, 7, 5, 3] dan [4, 7, 5, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 1: 7 -> 29
# Mutasi pada kromosom 5 gen 2: 5 -> 21
# Generasi 62 Fitness Terbaik: 0.0625
#
# Generasi 63:
# Evaluasi fitness: [4, 29, 5, 3] -> Fitness: 0.01667
# Evaluasi fitness: [4, 29, 5, 3] -> Fitness: 0.01667
# Evaluasi fitness: [4, 29, 5, 3] -> Fitness: 0.01667
# Evaluasi fitness: [4, 29, 5, 3] -> Fitness: 0.01667
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 7, 21, 3] -> Fitness: 0.01562
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3], [4, 7, 5, 3]]
# Melakukan crossover...
# Crossover antara [4, 7, 5, 3] dan [4, 7, 5, 3] menghasilkan [4, 7, 5, 3] dan [4, 7, 5, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 2: 5 -> 19
# Mutasi pada kromosom 4 gen 1: 7 -> 3
# Generasi 63 Fitness Terbaik: 0.0625
#
# Generasi 64:
# Evaluasi fitness: [4, 3, 19, 3] -> Fitness: 0.02000
# Evaluasi fitness: [4, 3, 19, 3] -> Fitness: 0.02000
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 7, 5, 3] -> Fitness: 0.06250
# Evaluasi fitness: [4, 3, 19, 3] -> Fitness: 0.02000
# Evaluasi fitness: [4, 3, 19, 3] -> Fitness: 0.02000
# Melakukan seleksi menggunakan metode roulette wheel...
# ...
# Populasi setelah seleksi: [[1, 7, 12, 3], [6, 3, 5, 3], [6, 3, 5, 3], [6, 3, 5, 3], [6, 3, 5, 3], [6, 3, 5, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 6 -> 8
# Mutasi pada kromosom 1 gen 2: 5 -> 30
# Generasi 78 Fitness Terbaik: 0.1
#
# Generasi 79:
# Evaluasi fitness: [1, 7, 12, 3] -> Fitness: 0.02941
# Evaluasi fitness: [8, 3, 30, 3] -> Fitness: 0.01149
# Evaluasi fitness: [8, 3, 30, 3] -> Fitness: 0.01149
# Evaluasi fitness: [8, 3, 30, 3] -> Fitness: 0.01149
# Evaluasi fitness: [8, 3, 30, 3] -> Fitness: 0.01149
# Evaluasi fitness: [8, 3, 30, 3] -> Fitness: 0.01149
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[8, 3, 30, 3], [1, 7, 12, 3], [8, 3, 30, 3], [1, 7, 12, 3], [8, 3, 30, 3], [1, 7, 12, 3]]
# Melakukan crossover...
# Crossover antara [8, 3, 30, 3] dan [1, 7, 12, 3] menghasilkan [8, 3, 12, 3] dan [1, 7, 30, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 3: 3 -> 7
# Mutasi pada kromosom 4 gen 2: 30 -> 4
# Generasi 79 Fitness Terbaik: 0.029411764705882353
#
# Generasi 80:
# Evaluasi fitness: [8, 3, 4, 3] -> Fitness: 0.11111
# Evaluasi fitness: [1, 7, 12, 7] -> Fitness: 0.02000
# Evaluasi fitness: [8, 3, 12, 3] -> Fitness: 0.03030
# Evaluasi fitness: [1, 7, 30, 3] -> Fitness: 0.01136
# Evaluasi fitness: [8, 3, 4, 3] -> Fitness: 0.11111
# Evaluasi fitness: [1, 7, 12, 7] -> Fitness: 0.02000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[8, 3, 4, 3], [8, 3, 4, 3], [8, 3, 12, 3], [8, 3, 4, 3], [1, 7, 12, 7], [1, 7, 12, 7]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 3: 3 -> 25
# Mutasi pada kromosom 3 gen 1: 3 -> 27
# Generasi 80 Fitness Terbaik: 0.1111111111111111
#
# Generasi 81:
# Evaluasi fitness: [8, 27, 4, 25] -> Fitness: 0.00690
# Evaluasi fitness: [8, 27, 4, 25] -> Fitness: 0.00690
# Evaluasi fitness: [8, 3, 12, 3] -> Fitness: 0.03030
# Evaluasi fitness: [8, 27, 4, 25] -> Fitness: 0.00690
# Evaluasi fitness: [1, 7, 12, 7] -> Fitness: 0.02000
# Evaluasi fitness: [1, 7, 12, 7] -> Fitness: 0.02000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[8, 3, 12, 3], [8, 27, 4, 25], [8, 3, 12, 3], [1, 7, 12, 7], [8, 27, 4, 25], [1, 7, 12, 7]]
# Melakukan crossover...
# Crossover antara [8, 3, 12, 3] dan [8, 27, 4, 25] menghasilkan [8, 3, 12, 25] dan [8, 27, 4, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 2: 12 -> 3
# Mutasi pada kromosom 0 gen 3: 25 -> 21
# Generasi 81 Fitness Terbaik: 0.030303030303030304
#
# Generasi 82:
# Evaluasi fitness: [8, 3, 12, 21] -> Fitness: 0.00952
# Evaluasi fitness: [8, 27, 4, 3] -> Fitness: 0.01754
# Evaluasi fitness: [8, 3, 3, 3] -> Fitness: 0.16667
# Evaluasi fitness: [1, 7, 12, 7] -> Fitness: 0.02000
# Evaluasi fitness: [8, 27, 4, 25] -> Fitness: 0.00690
# Evaluasi fitness: [1, 7, 12, 7] -> Fitness: 0.02000
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[8, 3, 3, 3], [8, 3, 3, 3], [8, 3, 3, 3], [8, 3, 3, 3], [8, 3, 3, 3], [8, 3, 3, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 0: 8 -> 9
# Mutasi pada kromosom 1 gen 1: 3 -> 11
# Generasi 82 Fitness Terbaik: 0.16666666666666666
#
# Generasi 83:
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [9, 11, 3, 3] dan [9, 11, 3, 3] menghasilkan [9, 11, 3, 3] dan [9, 11, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 2: 3 -> 28
# Mutasi pada kromosom 4 gen 0: 9 -> 23
# Generasi 83 Fitness Terbaik: 0.043478260869565216
#
# Generasi 84:
# Evaluasi fitness: [23, 11, 28, 3] -> Fitness: 0.00893
# Evaluasi fitness: [23, 11, 28, 3] -> Fitness: 0.00893
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [23, 11, 28, 3] -> Fitness: 0.00893
# Evaluasi fitness: [23, 11, 28, 3] -> Fitness: 0.00893
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[23, 11, 28, 3], [23, 11, 28, 3], [23, 11, 28, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [23, 11, 28, 3] dan [23, 11, 28, 3] menghasilkan [23, 11, 28, 3] dan [23, 11, 28, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 1: 11 -> 22
# Mutasi pada kromosom 0 gen 2: 28 -> 24
# Generasi 84 Fitness Terbaik: 0.043478260869565216
#
# Generasi 85:
# Evaluasi fitness: [23, 22, 24, 3] -> Fitness: 0.00820
# Evaluasi fitness: [23, 11, 28, 3] -> Fitness: 0.00893
# Evaluasi fitness: [23, 11, 28, 3] -> Fitness: 0.00893
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [23, 11, 28, 3], [23, 11, 28, 3], [9, 11, 3, 3], [23, 11, 28, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [23, 11, 28, 3] dan [9, 11, 3, 3] menghasilkan [23, 11, 28, 3] dan [9, 11, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 1: 11 -> 16
# Mutasi pada kromosom 2 gen 3: 3 -> 3
# Generasi 85 Fitness Terbaik: 0.043478260869565216
#
# Generasi 86:
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [23, 16, 28, 3] -> Fitness: 0.00820
# Evaluasi fitness: [23, 11, 28, 3] -> Fitness: 0.00893
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [23, 16, 28, 3] -> Fitness: 0.00820
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [9, 11, 3, 3] dan [9, 11, 3, 3] menghasilkan [9, 11, 3, 3] dan [9, 11, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 3: 3 -> 26
# Mutasi pada kromosom 4 gen 2: 3 -> 21
# Generasi 86 Fitness Terbaik: 0.043478260869565216
#
# Generasi 87:
# Evaluasi fitness: [9, 11, 3, 26] -> Fitness: 0.00870
# Evaluasi fitness: [9, 11, 3, 26] -> Fitness: 0.00870
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 21, 3] -> Fitness: 0.01299
# Evaluasi fitness: [9, 11, 3, 26] -> Fitness: 0.00870
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 21, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 26], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [9, 11, 21, 3] dan [9, 11, 3, 3] menghasilkan [9, 11, 3, 3] dan [9, 11, 21, 3]
# Crossover antara [9, 11, 3, 3] dan [9, 11, 3, 3] menghasilkan [9, 11, 3, 3] dan [9, 11, 3, 3]
# Crossover antara [9, 11, 3, 26] dan [9, 11, 3, 3] menghasilkan [9, 11, 3, 3] dan [9, 11, 3, 26]
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 1: 11 -> 11
# Mutasi pada kromosom 5 gen 3: 26 -> 24
# Generasi 87 Fitness Terbaik: 0.043478260869565216
#
# Generasi 88:
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 21, 3] -> Fitness: 0.01299
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 24] -> Fitness: 0.00935
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 21, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 2: 3 -> 9
# Mutasi pada kromosom 4 gen 0: 9 -> 2
# Generasi 88 Fitness Terbaik: 0.043478260869565216
#
# Generasi 89:
# Evaluasi fitness: [9, 11, 9, 3] -> Fitness: 0.02439
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [2, 11, 21, 3] -> Fitness: 0.01429
# Evaluasi fitness: [9, 11, 9, 3] -> Fitness: 0.02439
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [9, 11, 3, 3] dan [9, 11, 3, 3] menghasilkan [9, 11, 3, 3] dan [9, 11, 3, 3]
# Crossover antara [9, 11, 3, 3] dan [9, 11, 3, 3] menghasilkan [9, 11, 3, 3] dan [9, 11, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 2: 3 -> 21
# Mutasi pada kromosom 0 gen 3: 3 -> 2
# Generasi 89 Fitness Terbaik: 0.043478260869565216
#
# Generasi 90:
# Evaluasi fitness: [9, 11, 3, 2] -> Fitness: 0.05263
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 21, 3] -> Fitness: 0.01299
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 2], [9, 11, 3, 2]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 5 gen 3: 2 -> 4
# Mutasi pada kromosom 5 gen 2: 3 -> 26
# Generasi 90 Fitness Terbaik: 0.05263157894736842
#
# Generasi 91:
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 26, 4] -> Fitness: 0.01042
# Evaluasi fitness: [9, 11, 26, 4] -> Fitness: 0.01042
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 26, 4], [9, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [9, 11, 3, 3] dan [9, 11, 26, 4] menghasilkan [9, 11, 26, 4] dan [9, 11, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 0: 9 -> 7
# Mutasi pada kromosom 0 gen 0: 9 -> 29
# Generasi 91 Fitness Terbaik: 0.043478260869565216
#
# Generasi 92:
# Evaluasi fitness: [29, 11, 3, 3] -> Fitness: 0.02326
# Evaluasi fitness: [7, 11, 3, 3] -> Fitness: 0.04762
# Evaluasi fitness: [9, 11, 26, 4] -> Fitness: 0.01042
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [7, 11, 3, 3] -> Fitness: 0.04762
# Evaluasi fitness: [29, 11, 3, 3] -> Fitness: 0.02326
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [7, 11, 3, 3], [7, 11, 3, 3], [9, 11, 3, 3], [7, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [7, 11, 3, 3] dan [9, 11, 3, 3] menghasilkan [7, 11, 3, 3] dan [9, 11, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 1 gen 0: 7 -> 16
# Mutasi pada kromosom 2 gen 2: 3 -> 12
# Generasi 92 Fitness Terbaik: 0.047619047619047616
#
# Generasi 93:
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [16, 11, 12, 3] -> Fitness: 0.01754
# Evaluasi fitness: [16, 11, 12, 3] -> Fitness: 0.01754
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [7, 11, 3, 3] -> Fitness: 0.04762
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[7, 11, 3, 3], [16, 11, 12, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [7, 11, 3, 3] dan [16, 11, 12, 3] menghasilkan [7, 11, 12, 3] dan [16, 11, 3, 3]
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 3: 3 -> 1
# Mutasi pada kromosom 1 gen 2: 3 -> 13
# Generasi 93 Fitness Terbaik: 0.047619047619047616
#
# Generasi 94:
# Evaluasi fitness: [7, 11, 12, 1] -> Fitness: 0.02500
# Evaluasi fitness: [16, 11, 13, 3] -> Fitness: 0.01667
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[16, 11, 13, 3], [9, 11, 3, 3], [7, 11, 12, 1], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 3, 3]]
# Melakukan crossover...
# Crossover antara [7, 11, 12, 1] dan [9, 11, 3, 3] menghasilkan [7, 11, 3, 3] dan [9, 11, 12, 1]
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 2: 3 -> 29
# Mutasi pada kromosom 5 gen 0: 9 -> 28
# Generasi 94 Fitness Terbaik: 0.043478260869565216
#
# Generasi 95:
# Evaluasi fitness: [16, 11, 13, 3] -> Fitness: 0.01667
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [7, 11, 29, 3] -> Fitness: 0.01010
# Evaluasi fitness: [9, 11, 12, 1] -> Fitness: 0.02381
# Evaluasi fitness: [9, 11, 3, 3] -> Fitness: 0.04348
# Evaluasi fitness: [28, 11, 3, 3] -> Fitness: 0.02381
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 12, 1], [9, 11, 3, 3], [9, 11, 3, 3], [9, 11, 12, 1]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 0: 9 -> 29
# Mutasi pada kromosom 4 gen 2: 3 -> 21
# Generasi 95 Fitness Terbaik: 0.043478260869565216
#
# Generasi 96:
# Evaluasi fitness: [29, 11, 21, 3] -> Fitness: 0.01031
# Evaluasi fitness: [29, 11, 21, 3] -> Fitness: 0.01031
# Evaluasi fitness: [9, 11, 12, 1] -> Fitness: 0.02381
# Evaluasi fitness: [29, 11, 21, 3] -> Fitness: 0.01031
# Evaluasi fitness: [29, 11, 21, 3] -> Fitness: 0.01031
# Evaluasi fitness: [9, 11, 12, 1] -> Fitness: 0.02381
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[29, 11, 21, 3], [9, 11, 12, 1], [29, 11, 21, 3], [9, 11, 12, 1], [29, 11, 21, 3], [9, 11, 12, 1]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 4 gen 0: 29 -> 14
# Mutasi pada kromosom 0 gen 1: 11 -> 11
# Generasi 96 Fitness Terbaik: 0.023809523809523808
#
# Generasi 97:
# Evaluasi fitness: [14, 11, 21, 3] -> Fitness: 0.01220
# Evaluasi fitness: [9, 11, 12, 1] -> Fitness: 0.02381
# Evaluasi fitness: [14, 11, 21, 3] -> Fitness: 0.01220
# Evaluasi fitness: [9, 11, 12, 1] -> Fitness: 0.02381
# Evaluasi fitness: [14, 11, 21, 3] -> Fitness: 0.01220
# Evaluasi fitness: [9, 11, 12, 1] -> Fitness: 0.02381
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 12, 1], [9, 11, 12, 1], [9, 11, 12, 1], [14, 11, 21, 3], [14, 11, 21, 3], [9, 11, 12, 1]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 3 gen 0: 14 -> 24
# Mutasi pada kromosom 2 gen 3: 1 -> 9
# Generasi 97 Fitness Terbaik: 0.023809523809523808
#
# Generasi 98:
# Evaluasi fitness: [9, 11, 12, 9] -> Fitness: 0.01351
# Evaluasi fitness: [9, 11, 12, 9] -> Fitness: 0.01351
# Evaluasi fitness: [9, 11, 12, 9] -> Fitness: 0.01351
# Evaluasi fitness: [24, 11, 21, 3] -> Fitness: 0.01087
# Evaluasi fitness: [24, 11, 21, 3] -> Fitness: 0.01087
# Evaluasi fitness: [9, 11, 12, 9] -> Fitness: 0.01351
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[9, 11, 12, 9], [9, 11, 12, 9], [24, 11, 21, 3], [9, 11, 12, 9], [9, 11, 12, 9], [9, 11, 12, 9]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 2 gen 0: 24 -> 16
# Mutasi pada kromosom 4 gen 0: 9 -> 27
# Generasi 98 Fitness Terbaik: 0.013513513513513514
#
# Generasi 99:
# Evaluasi fitness: [27, 11, 12, 9] -> Fitness: 0.01087
# Evaluasi fitness: [27, 11, 12, 9] -> Fitness: 0.01087
# Evaluasi fitness: [16, 11, 21, 3] -> Fitness: 0.01190
# Evaluasi fitness: [27, 11, 12, 9] -> Fitness: 0.01087
# Evaluasi fitness: [27, 11, 12, 9] -> Fitness: 0.01087
# Evaluasi fitness: [27, 11, 12, 9] -> Fitness: 0.01087
# Melakukan seleksi menggunakan metode roulette wheel...
# Populasi setelah seleksi: [[16, 11, 21, 3], [27, 11, 12, 9], [16, 11, 21, 3], [27, 11, 12, 9], [27, 11, 12, 9], [27, 11, 12, 9]]
# Melakukan crossover...
# Melakukan mutasi...
# Mutasi pada kromosom 0 gen 3: 3 -> 22
# Mutasi pada kromosom 4 gen 2: 12 -> 22
# Generasi 99 Fitness Terbaik: 0.011904761904761904
# Tidak ditemukan solusi yang tepat. Pendekatan terbaik: [16, 11, 21, 22]
#
# Solusi terbaik: a = 16, b = 11, c = 21, d = 22
